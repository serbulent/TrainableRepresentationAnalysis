# %%
import tqdm
import multiprocessing
import pandas as pd
import numpy as np
import scipy.stats

from sklearn import linear_model
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler

# %%
def load_representation(multi_col_representation_vector_file_path):
    multi_col_representation_vector = pd.read_csv(multi_col_representation_vector_file_path)
    vals = multi_col_representation_vector.iloc[:,1:(len(multi_col_representation_vector.columns))]
    original_values_as_df = pd.DataFrame({'PDB_ID': pd.Series([], dtype='str'),'Vector': pd.Series([], dtype='object')})
    for index, row in tqdm.tqdm(vals.iterrows(), total = len(vals)):
        list_of_floats = [float(item) for item in list(row)]
        original_values_as_df.loc[index] = [multi_col_representation_vector.iloc[index]['PDB_ID']] + [list_of_floats]
    return original_values_as_df

# %%
ppi_affinity_file = "/media/DATA/serbulent/DATA/Thesis/ReviewPaper/generalized_representation_benchmark/DATA/auxilary_input/skempi_pipr/SKEMPI_all_dg_avg.txt"

# %%
ppi_affinity_df = pd.read_csv(ppi_affinity_file,sep="\t",header=None)

# %%
ppi_affinity_df.columns = ['Protein1', 'Protein2', 'Affinity']

# %%
ppi_affinity_df[ppi_affinity_df['Protein1'].str.contains("wt") & ppi_affinity_df['Protein2'].str.contains("wt")].to_csv("wild_type_interactions.csv",index=False)

# %%
len(set(ppi_affinity_df[ppi_affinity_df['Protein1'].str.contains("wt") & ppi_affinity_df['Protein2'].str.contains("wt")]['Protein1']))
# Out:
# 158

# %%
ppi_affinity_df[ppi_affinity_df['Protein1'].str.contains("wt") & ppi_affinity_df['Protein2'].str.contains("wt")]['Protein1']
# Out:
# 138      1A22_A_wt
# 182      1A4Y_A_wt
# 195      1ACB_E_wt
# 206     1AHW_AB_wt
# 223      1AK4_A_wt
#            ...
# 2609    3HFM_HL_wt
# 2660     3NPS_A_wt
# 2917     3SGB_E_wt
# 2940     3TGK_E_wt
# 2947     4CPA_A_wt
# Name: Protein1, Length: 158, dtype: object

# %%
len(set(list(ppi_affinity_df['Protein1'])))
# Out:
# 764

# %%
skempi_vectors_path = "/media/DATA/serbulent/DATA/Thesis/ReviewPaper/generalized_representation_benchmark\
/DATA/representation_vectors/skempi/"

# %%
seqvec_skempi_vectors_df = load_representation(skempi_vectors_path+"skempi_bert_avg_representation_multi_col.csv")
# Out:
# 100%|██████████| 2882/2882 [00:05<00:00, 544.05it/s]

# %%
seqvec_skempi_vectors_df
# Out:
#                                                  PDB_ID  \
# 0                                             1CSE_E_wt
# 1                                             1CSE_I_wt
# 2                                         1CSE_I_LI45G_
# 3                                         1CSE_I_LI45S_
# 4                                         1CSE_I_LI45P_
# ...                                                 ...
# 2877  1PPF_I_EI10D_AI15V_TI17S_EI19D_RI21M_KI29T_GI3...
# 2878  1PPF_I_EI10D_KI13R_AI15V_EI19D_RI21M_GI32S_EI4...
# 2879  1PPF_I_EI10D_AI15V_EI19D_RI21M_GI32S_EI43D_LI4...
# 2880                    1PPF_I_EI10D_LI18F_RI21M_EI43D_
# 2881                                1PPF_I_AI15V_TI17S_
#
#                                                  Vector
# 0     [0.4469349086284637, -0.3453298509120941, -0.1...
# 1     [0.4469349086284637, -0.3453298509120941, -0.1...
# 2     [0.4469349086284637, -0.3453298509120941, -0.1...
# 3     [0.4469349086284637, -0.3453298509120941, -0.1...
# 4     [0.4469349086284637, -0.3453298509120941, -0.1...
# ...                                                 ...
# 2877  [0.4469349086284637, -0.3453298509120941, -0.1...
# 2878  [0.4469349086284637, -0.3453298509120941, -0.1...
# 2879  [0.4469349086284637, -0.3453298509120941, -0.1...
# 2880  [0.4469349086284637, -0.3453298509120941, -0.1...
# 2881  [0.4469349086284637, -0.3453298509120941, -0.1...
#
# [2882 rows x 2 columns]

# %% [markdown]
# ## Calculate vector element-wise multiplication as described in https://academic.oup.com/bioinformatics/article/35/14/i305/5529260

# %%
'1CSE_I_LI45S_' in seqvec_skempi_vectors_df['PDB_ID']
# Out:
# False

# %%
rep_prot_list = list(seqvec_skempi_vectors_df['PDB_ID'])

# %%
rep_prot_list
# Out:
# ['1CSE_E_wt',
#  '1CSE_I_wt',
#  '1CSE_I_LI45G_',
#  '1CSE_I_LI45S_',
#  '1CSE_I_LI45P_',
#  '1CSE_I_LI45I_',
#  '1CSE_I_LI45D_',
#  '1CSE_I_LI45E_',
#  '1ACB_E_wt',
#  '1ACB_I_wt',
#  '1ACB_I_LI45G_',
#  '1ACB_I_LI45S_',
#  '1ACB_I_LI45P_',
#  '1ACB_I_LI45I_',
#  '1ACB_I_LI45D_',
#  '1ACB_I_LI45E_',
#  '1SBN_E_wt',
#  '1SBN_I_wt',
#  '1SBN_I_RI45K_',
#  '1SIB_E_wt',
#  '1SIB_I_wt',
#  '1SIB_I_KI53R_',
#  '1TM1_E_wt',
#  '1TM1_I_wt',
#  '1TM1_I_YI61A_',
#  '1TM1_I_YI61G_',
#  '1TM1_I_RI65A_',
#  '1TM1_I_RI67A_',
#  '1TM1_I_RI67C_',
#  '1TM1_I_RI67A_RI65A_',
#  '1TM1_I_TI58D_',
#  '1TM1_I_TI58A_',
#  '1TM1_I_EI60A_',
#  '1TM1_I_TI58A_EI60A_',
#  '1TM1_I_TI58D_EI60A_',
#  '1TM1_I_VI70A_',
#  '1Y1K_E_wt',
#  '1Y1K_I_wt',
#  '1Y1K_I_AI58T_',
#  '1Y33_E_wt',
#  '1Y33_I_wt',
#  '1Y33_I_PI58T_',
#  '1Y34_E_wt',
#  '1Y34_I_wt',
#  '1Y34_I_AI60E_',
#  '1Y3B_E_wt',
#  '1Y3B_I_wt',
#  '1Y3B_I_SI60E_',
#  '1Y4A_E_wt',
#  '1Y4A_I_wt',
#  '1Y4A_I_SI60E_RI59M_',
#  '1Y3C_E_wt',
#  '1Y3C_I_wt',
#  '1Y3C_I_AI62R_',
#  '1Y48_E_wt',
#  '1Y48_I_wt',
#  '1Y48_I_AI65R_',
#  '1Y3D_E_wt',
#  '1Y3D_I_wt',
#  '1Y3D_I_AI67R_',
#  '1TM1_I_TI58P_',
#  '1TM1_I_EI60S_',
#  '1TM1_I_EI60S_MI59R_',
#  '1TM1_I_RI62A_',
#  '1TM4_E_wt',
#  '1TM4_I_wt',
#  '1TM4_I_GI59M_',
#  '1TM5_E_wt',
#  '1TM5_I_wt',
#  '1TM5_I_AI59M_',
#  '1TM3_E_wt',
#  '1TM3_I_wt',
#  '1TM3_I_KI59M_',
#  '1TM7_E_wt',
#  '1TM7_I_wt',
#  '1TM7_I_YI59M_',
#  '1TMG_E_wt',
#  '1TMG_I_wt',
#  '1TMG_I_FI59M_',
#  '1TO1_E_wt',
#  '1TO1_I_wt',
#  '1TO1_I_AI61Y_',
#  '1TM1_I_MI59G_',
#  '1TM1_I_MI59A_',
#  '1TM1_I_MI59K_',
#  '1TM1_I_MI59Y_',
#  '1TM1_I_MI59F_',
#  '2SIC_E_wt',
#  '2SIC_I_wt',
#  '2SIC_I_MI73E_',
#  '2SIC_I_MI73D_',
#  '2SIC_I_MI73H_',
#  '2SIC_I_MI73K_',
#  '2SIC_I_MI73R_',
#  '2SIC_I_MI73G_',
#  '2SIC_I_MI73A_',
#  '2SIC_I_MI73L_',
#  '2SIC_I_MI73V_',
#  '2SIC_I_MI73I_',
#  '1IAR_A_wt',
#  '1IAR_B_wt',
#  '1IAR_A_IA5A_',
#  '1IAR_A_IA5R_',
#  '1IAR_A_TA6A_',
#  '1IAR_A_TA6D_',
#  '1IAR_A_QA8A_',
#  '1IAR_A_QA8R_',
#  '1IAR_A_EA9Q_',
#  '1IAR_A_IA11A_',
#  '1IAR_A_KA12S_',
#  '1IAR_A_KA12E_',
#  '1IAR_A_TA13A_',
#  '1IAR_A_TA13D_',
#  '1IAR_A_NA15A_',
#  '1IAR_A_NA15D_',
#  '1IAR_A_SA16A_',
#  '1IAR_A_SA16D_',
#  '1IAR_A_EA19A_',
#  '1IAR_A_EA19R_',
#  '1IAR_A_RA53Q_',
#  '1IAR_A_KA77A_',
#  '1IAR_A_KA77E_',
#  '1IAR_A_QA78A_',
#  '1IAR_A_QA78E_',
#  '1IAR_A_RA81A_',
#  '1IAR_A_RA81E_',
#  '1IAR_A_FA82A_',
#  '1IAR_A_FA82D_',
#  '1IAR_A_KA84A_',
#  '1IAR_A_KA84D_',
#  '1IAR_A_RA85A_',
#  '1IAR_A_RA85E_',
#  '1IAR_A_RA88Q_',
#  '1IAR_A_RA88A_',
#  '1IAR_A_NA89A_',
#  '1IAR_A_WA91A_',
#  '1IAR_A_WA91D_',
#  '1BRS_A_wt',
#  '1BRS_D_wt',
#  '1BRS_A_KA27A_',
#  '1BRS_A_RA59A_',
#  '1BRS_A_RA83Q_',
#  '1BRS_A_RA87A_',
#  '1BRS_A_HA102A_',
#  '1BRS_D_YD29F_',
#  '1BRS_D_YD29A_',
#  '1BRS_D_DD35A_',
#  '1BRS_D_WD38F_',
#  '1BRS_D_DD39A_',
#  '1BRS_D_TD42A_',
#  '1BRS_D_WD44F_',
#  '1BRS_D_ED76A_',
#  '1BRS_D_ED80A_',
#  '1BRS_A_EA73Q_',
#  '1BRS_A_EA73W_',
#  '1BRS_A_EA73Y_',
#  '1BRS_A_EA73F_',
#  '1BRS_A_EA73C_',
#  '1BRS_A_EA73S_',
#  '1BRS_A_EA73A_',
#  '1BRS_A_RA59K_',
#  '1BRS_A_HA102Q_',
#  '1BRS_A_HA102D_',
#  '1BRS_A_HA102G_',
#  '1BRS_A_HA102L_',
#  '1BRS_A_HA102Q_RA59K_',
#  '1BRS_A_HA102Q_RA59A_',
#  '1B2U_A_wt',
#  '1B2U_D_wt',
#  '1B2U_A_AA27K_',
#  '1B2U_D_AD36D_',
#  '1B2S_A_wt',
#  '1B2S_D_wt',
#  '1B2S_A_AA27K_',
#  '1B2S_D_AD43T_',
#  '1B3S_A_wt',
#  '1B3S_D_wt',
#  '1B3S_A_AA102H_',
#  '1B3S_D_FD30Y_',
#  '1X1W_A_wt',
#  '1X1W_D_wt',
#  '1X1W_D_AD80E_',
#  '1X1X_A_wt',
#  '1X1X_D_wt',
#  '1X1X_D_AD76E_',
#  '1BRS_A_WA35F_',
#  '1BRS_A_DA54A_',
#  '1BRS_A_NA58A_',
#  '1BRS_A_EA60A_',
#  '1SBB_A_wt',
#  '1SBB_B_wt',
#  '1SBB_B_LB20T_',
#  '1SBB_B_VB26Y_',
#  '1SBB_B_YB91V_',
#  '1JCK_A_wt',
#  '1JCK_B_wt',
#  '1JCK_B_TB20A_',
#  '1JCK_B_YB26A_',
#  '1JCK_B_NB60A_',
#  '1JCK_B_YB90A_',
#  '1JCK_B_VB91A_',
#  '1JCK_B_KB103A_',
#  '1JCK_B_FB176A_',
#  '1GCQ_AB_wt',
#  '1GCQ_C_wt',
#  '1GCQ_C_PC595A_',
#  '1GCQ_C_AC632G_',
#  '1GCQ_C_WC637Y_',
#  '1GCQ_C_PC657A_',
#  '1GCQ_C_PC608A_',
#  '1GCQ_C_PC609A_',
#  '1GCQ_C_GC611V_',
#  '1E96_A_wt',
#  '1E96_B_wt',
#  '1E96_A_NA26H_',
#  '1E96_A_IA33N_',
#  '1E96_A_DA38N_',
#  '1E96_A_MA45T_',
#  '1E96_A_KA132E_',
#  '1E96_A_LA134R_',
#  '1AK4_A_wt',
#  '1AK4_D_wt',
#  '1AK4_D_PD485A_',
#  '1AK4_D_VD486A_',
#  '1AK4_D_HD487A_',
#  '1AK4_D_HD487Q_',
#  '1AK4_D_HD487R_',
#  '1AK4_D_AD488V_',
#  '1AK4_D_AD488G_',
#  '1AK4_D_GD489A_',
#  '1AK4_D_GD489V_',
#  '1AK4_D_PD490A_',
#  '1AK4_D_ID491A_',
#  '1AK4_D_ID491V_',
#  '1AK4_D_AD492G_',
#  '1AK4_D_AD492V_',
#  '1AK4_D_PD493A_',
#  '1M9E_A_wt',
#  '1M9E_D_wt',
#  '1M9E_D_AD87H_',
#  '2B42_A_wt',
#  '2B42_B_wt',
#  '2B42_A_HA374A_',
#  '2B42_A_HA374Q_',
#  '2B42_A_HA374K_',
#  '2I26_N_wt',
#  '2I26_L_wt',
#  '2I26_N_AN30V_',
#  '2I26_N_SN61R_',
#  '2HLE_A_wt',
#  '2HLE_B_wt',
#  '2HLE_A_KA149Q_',
#  '2HLE_A_LA95R_',
#  '2I9B_A_wt',
#  '2I9B_E_wt',
#  '2I9B_E_RE137A_',
#  '2I9B_E_KE139A_',
#  '2I9B_E_RE142A_',
#  '2I9B_E_HE143A_',
#  '2I9B_E_RE145A_',
#  '1AHW_AB_wt',
#  '1AHW_C_wt',
#  '1AHW_C_TC121A_KC122K_',
#  '1AHW_C_KC149A_DC150A_',
#  '1AHW_C_YC157A_',
#  '1AHW_C_KC165A_KC166A_',
#  '1AHW_C_TC167A_',
#  '1AHW_C_TC170A_',
#  '1AHW_C_LC176A_',
#  '1AHW_C_DC178A_',
#  '1AHW_C_TC197A_',
#  '1AHW_C_VC198A_',
#  '1AHW_C_NC199A_',
#  '1UUZ_A_wt',
#  '1UUZ_D_wt',
#  '1UUZ_A_HA62Q_',
#  '1UUZ_A_HA62N_',
#  '1UUZ_A_HA62D_',
#  '1UUZ_A_HA62A_',
#  '1UUZ_A_CA64A_',
#  '1DVF_AB_wt',
#  '1DVF_CD_wt',
#  '1DVF_AB_HA30A_',
#  '1DVF_AB_YA32A_',
#  '1DVF_AB_YA49A_',
#  '1DVF_AB_YA50A_',
#  '1DVF_AB_WA92A_',
#  '1DVF_AB_SA93A_',
#  '1DVF_AB_TB30A_',
#  '1DVF_AB_YB32A_',
#  '1DVF_AB_WB52A_',
#  '1DVF_AB_DB54A_',
#  '1DVF_AB_NB56A_',
#  '1DVF_AB_DB58A_',
#  '1DVF_AB_EB98A_',
#  '1DVF_AB_RB99A_',
#  '1DVF_AB_DB100A_',
#  '1DVF_AB_YB101F_',
#  '1DVF_CD_YD98A_',
#  '1DVF_CD_YC49A_',
#  '1DVF_CD_QD100A_',
#  '1DVF_CD_ND54A_',
#  '1DVF_CD_RD100bA_',
#  '1DVF_CD_KD30A_',
#  '1DVF_CD_HD33A_',
#  '1DVF_CD_DD52A_',
#  '1DVF_CD_ID97A_',
#  '1VFB_AB_wt',
#  '1VFB_C_wt',
#  '1VFB_AB_HA30A_',
#  '1VFB_AB_YA32A_',
#  '1VFB_AB_YA49A_',
#  '1VFB_AB_YA50A_',
#  '1VFB_AB_WA92A_',
#  '1VFB_AB_SA93A_',
#  '1VFB_AB_TB30A_',
#  '1VFB_AB_YB32A_',
#  '1VFB_AB_WB52A_',
#  '1VFB_AB_DB54A_',
#  '1VFB_AB_NB56A_',
#  '1VFB_AB_DB58A_',
#  '1VFB_AB_EB98A_',
#  '1VFB_AB_RB99A_',
#  '1VFB_AB_DB100A_',
#  '1VFB_AB_YB101F_',
#  '1EFN_A_wt',
#  '1EFN_B_wt',
#  '1EFN_A_TA97H_EA98H_',
#  '1EFN_A_TA97H_',
#  '1EFN_A_IA96A_',
#  '2GOX_A_wt',
#  '2GOX_B_wt',
#  '2GOX_B_RB131A_',
#  '2GOX_B_NB138A_',
#  '3D5S_A_wt',
#  '3D5S_C_wt',
#  '3D5S_C_AC41R_',
#  '3D5R_A_wt',
#  '3D5R_C_wt',
#  '3D5R_C_AC48N_',
#  '2NOJ_A_wt',
#  '2NOJ_B_wt',
#  '2NOJ_B_RB75A_NB82A_',
#  '3BP8_A_wt',
#  '3BP8_C_wt',
#  '3BP8_A_FA136A_',
#  '3BP8_C_AC63F_',
#  '2VIS_AB_wt',
#  '2VIS_C_wt',
#  '2VIS_C_IC131T_',
#  '2VIR_AB_wt',
#  '2VIR_C_wt',
#  '2VIR_C_SC157L_',
#  '2VIR_C_TC131I_',
#  '2HRK_A_wt',
#  '2HRK_B_wt',
#  '2HRK_B_TB57V_',
#  '2HRK_A_TA127V_',
#  '2HRK_A_KA159A_',
#  '2WPT_A_wt',
#  '2WPT_B_wt',
#  '2WPT_A_DA33L_',
#  '2WPT_A_NA34V_',
#  '2WPT_A_RA38T_',
#  '2WPT_A_EA39H_',
#  '2WPT_A_RA42E_',
#  '2WPT_A_NA34V_RA38T_',
#  '2WPT_A_DA33L_NA34V_RA38T_',
#  '2WPT_A_NA34V_RA38T_RA42E_',
#  '2WPT_A_NA34V_RA38T_EA39H_RA42E_',
#  '2WPT_A_EA30A_',
#  '2WPT_A_DA33A_',
#  '2WPT_A_NA34A_',
#  '2WPT_A_VA37A_',
#  '2WPT_A_RA38A_',
#  '2WPT_A_EA41A_',
#  '2WPT_A_RA42A_',
#  '2WPT_A_SA50A_',
#  '2WPT_A_PA56A_',
#  '2WPT_B_FB86A_',
#  '2WPT_B_RB54A_',
#  '2WPT_B_NB72A_',
#  '2WPT_B_SB74A_',
#  '2WPT_B_NB75A_',
#  '2WPT_B_SB77A_',
#  '2WPT_B_SB78A_',
#  '2WPT_B_SB84A_',
#  '2WPT_B_TB87A_',
#  '2WPT_B_QB92A_',
#  '2WPT_B_KB97A_',
#  '2WPT_B_VB98A_',
#  '2VLP_A_wt',
#  '2VLP_B_wt',
#  '2VLP_B_AB54R_',
#  '2VLN_A_wt',
#  '2VLN_B_wt',
#  '2VLN_B_AB75N_',
#  '2VLQ_A_wt',
#  '2VLQ_B_wt',
#  '2VLQ_B_AB86F_',
#  '2VLO_A_wt',
#  '2VLO_B_wt',
#  '2VLO_B_AB97K_',
#  '1EMV_A_wt',
#  '1EMV_B_wt',
#  '1EMV_A_QA17E_LA18F_TA20K_TA21K_NA24R_DA26E_TA27G_SA28A_SA29T_EA32D_LA33D_VA34N_TA38R_HA39E_EA42R_MA43L_SA48D_KA57R_EA58D_GA59D_DA60R_DA61E_SA65E_NA69K_TA70E_VA71I_QA73E_',
#  '2WPT_A_EA17Q_FA18L_KA20T_KA21T_RA24N_EA26D_GA27T_AA28S_TA29S_DA32E_DA33L_NA34V_RA38T_EA39H_RA42E_LA43M_DA48S_RA57K_DA58E_DA59G_RA60D_EA61D_EA65S_KA69N_EA70T_IA71V_EA73Q_',
#  '1EMV_A_EA32D_LA33D_VA34N_TA38R_HA39E_EA42R_MA43L_SA48D_KA57R_EA58D_GA59D_DA60R_DA61E_SA65E_NA69K_TA70E_VA71I_QA73E_',
#  '2WPT_A_EA17Q_FA18L_KA20T_KA21T_RA24N_EA26D_GA27T_AA28S_TA29S_',
#  '1EMV_A_QA17E_LA18F_TA20K_TA21K_NA24R_DA26E_TA27G_SA28A_SA29T_SA65E_NA69K_TA70E_VA71I_QA73E_',
#  '2WPT_A_DA32E_DA33L_NA34V_RA38T_EA39H_RA42E_LA43M_DA48S_RA57K_DA58E_DA59G_RA60D_EA61D_',
#  '1EMV_A_QA17E_LA18F_TA20K_TA21K_NA24R_DA26E_TA27G_SA28A_SA29T_SA48D_KA57R_EA58D_GA59D_DA60R_DA61E_SA65E_NA69K_TA70E_VA71I_QA73E_',
#  '2WPT_A_DA32E_DA33L_NA34V_RA38T_EA39H_RA42E_LA43M_',
#  '1EMV_A_QA17E_LA18F_TA20K_TA21K_NA24R_SA48D_KA57R_EA58D_GA59D_DA60R_DA61E_SA65E_NA69K_TA70E_VA71I_QA73E_',
#  '2WPT_A_EA26D_GA27T_AA28S_TA29S_DA32E_DA33L_NA34V_RA38T_EA39H_RA42E_LA43M_',
#  '1EMV_A_QA17E_LA18F_SA48D_KA57R_EA58D_GA59D_DA60R_DA61E_SA65E_NA69K_TA70E_VA71I_QA73E_',
#  '2WPT_A_KA20T_KA21T_RA24N_EA26D_GA27T_AA28S_TA29S_DA32E_DA33L_NA34V_RA38T_EA39H_RA42E_LA43M_',
#  '1EMV_A_SA48D_KA57R_EA58D_GA59D_DA60R_DA61E_SA65E_NA69K_TA70E_VA71I_QA73E_',
#  '2WPT_A_EA17Q_FA18L_KA20T_KA21T_RA24N_EA26D_GA27T_AA28S_TA29S_DA32E_DA33L_NA34V_RA38T_EA39H_RA42E_LA43M_',
#  '1EMV_A_SA65E_NA69K_TA70E_VA71I_QA73E_',
#  '2WPT_A_EA17Q_FA18L_KA20T_KA21T_RA24N_EA26D_GA27T_AA28S_TA29S_DA32E_DA33L_NA34V_RA38T_EA39H_RA42E_LA43M_DA48S_RA57K_DA58E_DA59G_RA60D_EA61D_',
#  '1EMV_B_RB54A_',
#  '1EMV_B_NB72A_',
#  '1EMV_B_SB74A_',
#  '1EMV_B_NB75A_',
#  '1EMV_B_SB77A_',
#  '1EMV_B_SB78A_',
#  '1EMV_B_SB84A_',
#  '1EMV_B_FB86A_',
#  '1EMV_B_TB87A_',
#  '1EMV_B_QB92A_',
#  '1EMV_B_KB97A_',
#  '1EMV_B_VB98A_',
#  '1EMV_A_LA33A_',
#  '1EMV_A_VA34A_',
#  '1EMV_A_VA37A_',
#  '1EMV_A_YA54A_',
#  '1EMV_A_YA55A_',
#  '1EMV_A_CA23A_',
#  '1EMV_A_NA24A_',
#  '1EMV_A_DA26A_',
#  '1EMV_A_TA27A_',
#  '1EMV_A_SA28A_',
#  '1EMV_A_SA29A_',
#  '1EMV_A_EA30A_',
#  '1EMV_A_EA31A_',
#  '1EMV_A_EA32A_',
#  '1EMV_A_KA35A_',
#  '1EMV_A_LA36A_',
#  '1EMV_A_TA38A_',
#  '1EMV_A_EA41A_',
#  '1EMV_A_EA42A_',
#  '1EMV_A_TA44A_',
#  '1EMV_A_EA45A_',
#  '1EMV_A_HA46A_',
#  '1EMV_A_PA47A_',
#  '1EMV_A_SA48A_',
#  '1EMV_A_GA49A_',
#  '1EMV_A_SA50A_',
#  '1EMV_A_DA51A_',
#  '1EMV_A_LA52A_',
#  '1EMV_A_IA53A_',
#  '1EMV_A_PA56A_',
#  '1EMV_A_DA60A_',
#  '1EMV_A_SA63A_',
#  '1EMV_A_VA68A_',
#  '1EMV_A_NA69A_',
#  '1FR2_A_wt',
#  '1FR2_B_wt',
#  '1FR2_A_AA41E_',
#  '2GYK_A_wt',
#  '2GYK_B_wt',
#  '2GYK_A_AA51D_',
#  '1KIQ_AB_wt',
#  '1KIQ_C_wt',
#  '1KIQ_AB_FB101Y_',
#  '1KIP_AB_wt',
#  '1KIP_C_wt',
#  '1KIP_AB_AB32Y_',
#  '1KIR_AB_wt',
#  '1KIR_C_wt',
#  '1KIR_AB_SA50Y_',
#  '2B0Z_A_wt',
#  '2B0Z_B_wt',
#  '2B0Z_B_IB82F_',
#  '2B10_A_wt',
#  '2B10_B_wt',
#  '2B10_B_SB82F_',
#  '2B11_A_wt',
#  '2B11_B_wt',
#  '2B11_B_WB382F_',
#  '2B12_A_wt',
#  '2B12_B_wt',
#  '2B12_B_YB82F_',
#  '2PCC_A_wt',
#  '2PCC_B_wt',
#  '2PCC_A_DA34A_',
#  '2PCC_A_VA197A_',
#  '2PCC_A_EA290A_',
#  '2PCC_B_KB87A_',
#  '2PCC_B_KB72A_',
#  '2PCC_B_AB81G_',
#  '2PCB_A_wt',
#  '2PCB_B_wt',
#  '2PCB_A_EA291Q_',
#  '2PCB_A_EA32Q_',
#  '2PCB_A_EA35Q_',
#  '2PCB_A_AA193F_',
#  '2PCB_A_DA34N_',
#  '2PCB_A_EA290N_',
#  '2JEL_LH_wt',
#  '2JEL_P_wt',
#  '2JEL_P_FP2Y_',
#  '2JEL_P_FP2W_',
#  '2JEL_P_QP3K_',
#  '2JEL_P_QP4K_',
#  '2JEL_P_EP5D_',
#  '2JEL_P_EP5Q_',
#  '2JEL_P_VP6F_',
#  '2JEL_P_TP7N_',
#  '2JEL_P_TP7S_',
#  '2JEL_P_PP11E_',
#  '2JEL_P_NP12D_',
#  '2JEL_P_RP17G_',
#  '2JEL_P_RP17K_',
#  '2JEL_P_KP24E_',
#  '2JEL_P_KP27E_',
#  '2JEL_P_TP34Q_',
#  '2JEL_P_TP36Q_',
#  '2JEL_P_NP38T_',
#  '2JEL_P_SP41C_',
#  '2JEL_P_SP43C_',
#  '2JEL_P_SP46C_',
#  '2JEL_P_QP57E_',
#  '2JEL_P_TP62N_',
#  '2JEL_P_TP62A_',
#  '2JEL_P_SP64T_',
#  '2JEL_P_EP66K_',
#  '2JEL_P_EP68A_',
#  '2JEL_P_DP69E_',
#  '2JEL_P_EP70K_',
#  '2JEL_P_EP70A_',
#  '2JEL_P_QP71E_',
#  '2JEL_P_KP72R_',
#  '2JEL_P_KP72E_',
#  '2JEL_P_EP75R_',
#  '2JEL_P_HP76D_',
#  '2JEL_P_HP76A_',
#  '2JEL_P_KP79E_',
#  '2JEL_P_AP82S_',
#  '2JEL_P_EP83A_',
#  '2JEL_P_EP85Q_',
#  '2JEL_P_EP85D_',
#  '2JEL_P_EP85A_',
#  '2JEL_P_EP85K_',
#  '2OOB_A_wt',
#  '2OOB_B_wt',
#  '2OOB_A_KA935E_',
#  '2OOB_A_AA934S_KA935E_',
#  '2OOB_A_GA941S_',
#  '2OOB_A_IA955E_IA966E_',
#  '2O3B_A_wt',
#  '2O3B_B_wt',
#  '2O3B_B_EB24A_',
#  '2O3B_B_EB24D_',
#  '2O3B_B_EB24Q_',
#  '2O3B_B_QB74A_',
#  '2O3B_B_DB75E_',
#  '2O3B_B_DB75N_',
#  '2O3B_B_WB76A_',
#  '2O3B_B_QB74A_WB76A_',
#  '2J0T_A_wt',
#  '2J0T_D_wt',
#  '2J0T_D_VD4A_',
#  '2J0T_D_VD4I_',
#  '2J0T_D_VD4K_',
#  '2J0T_D_VD4S_',
#  '2J0T_D_SD68A_',
#  '2J0T_D_SD68E_',
#  '2J0T_D_SD68R_',
#  '2J0T_D_SD68Y_',
#  '2J0T_D_TD2L_',
#  '2J0T_D_TD2L_VD4S_',
#  '2J0T_D_TD2L_VD4S_SD68A_',
#  '2J0T_D_TD2R_',
#  '2J0T_D_TD2S_',
#  '2J0T_D_TD2S_VD4A_',
#  '2J0T_D_TD2S_VD4A_SD68Y_',
#  '2J0T_D_CD1S_FD12Y_',
#  '2J0T_D_TD2A_',
#  '2J0T_D_MD66A_',
#  '2J0T_D_VD69I_',
#  '2J0T_D_VD69T_',
#  '2J0T_D_VD69A_AD103V_',
#  '2J0T_D_CD70S_',
#  '2C0L_A_wt',
#  '2C0L_B_wt',
#  '2C0L_A_NA382A_',
#  '2C0L_A_QA586R_',
#  '2C0L_A_SA589Y_',
#  '2BTF_A_wt',
#  '2BTF_P_wt',
#  '2BTF_P_FP59A_',
#  '2BTF_P_VP60E_',
#  '2BTF_P_GP120F_',
#  '2BTF_P_KP125A_',
#  '2AJF_A_wt',
#  '2AJF_E_wt',
#  '2AJF_E_KE344R_',
#  '2AJF_E_FE360S_',
#  '2AJF_E_NE479K_',
#  '2AJF_E_TE487S_',
#  '2A9K_A_wt',
#  '2A9K_B_wt',
#  '2A9K_B_GB99D_',
#  '4CPA_A_wt',
#  '4CPA_I_wt',
#  '4CPA_I_PI36G_',
#  '4CPA_I_YI37G_',
#  '4CPA_I_YI37F_',
#  '4CPA_I_VI38G_',
#  '4CPA_I_VI38A_',
#  '4CPA_I_VI38L_',
#  '4CPA_I_VI38I_',
#  '4CPA_I_VI38F_',
#  '2ABZ_B_wt',
#  '2ABZ_E_wt',
#  '2ABZ_E_AE19C_AE43C_',
#  '1XD3_A_wt',
#  '1XD3_B_wt',
#  '1XD3_B_KB6A_',
#  '1XD3_B_KB27A_',
#  '1XD3_B_RB42L_',
#  '1XD3_B_RB54L_',
#  '1XD3_B_HB68N_',
#  '1XD3_B_RB72L_',
#  '1XD3_B_RB74L_',
#  '1XD3_B_EB24A_',
#  '1XD3_B_DB39A_',
#  '1XD3_B_EB51A_',
#  '1XD3_B_DB52A_',
#  '1XD3_B_DB58A_',
#  '1XD3_B_KB6R_',
#  '1XD3_B_LB8A_',
#  '1XD3_B_KB11R_',
#  '1XD3_B_KB27R_',
#  '1XD3_B_KB33R_',
#  '1XD3_B_IB44A_',
#  '1S1Q_A_wt',
#  '1S1Q_B_wt',
#  '1S1Q_A_VA43A_',
#  '1S1Q_A_FA44A_',
#  '1S1Q_A_NA45A_',
#  '1S1Q_A_DA46A_',
#  '1S1Q_A_WA75A_',
#  '1S1Q_A_FA88A_',
#  '1NCA_N_wt',
#  '1NCA_LH_wt',
#  '1NCA_LH_NH31Q_',
#  '1NCA_LH_EH96D_',
#  '1NCA_LH_DH97K_',
#  '1NCA_LH_NH98Q_',
#  '1N8O_ABC_wt',
#  '1N8O_E_wt',
#  '1N8O_E_ME84L_',
#  '1N8O_E_ME84K_',
#  '1N8O_E_ME84R_',
#  '1MQ8_A_wt',
#  '1MQ8_B_wt',
#  '1MQ8_B_CB161L_CB299F_',
#  '1MQ8_B_CB161L_CB299F_KB287C_KB294C_',
#  '1MQ8_B_CB161L_CB299F_EB284C_EB301C_',
#  '1MQ8_B_CB161L_CB299F_KB160C_TB300C_',
#  '1MQ8_B_CB161L_CB299F_LB289C_KB294C_',
#  '1MQ8_B_CB161L_KB160C_',
#  '1MQ8_B_CB299F_TB300C_',
#  '1MAH_A_wt',
#  '1MAH_F_wt',
#  '1MAH_A_FA295L_',
#  '1MAH_A_FA297I_',
#  '1MAH_A_FA297Y_',
#  '1MAH_A_FA338G_',
#  '1MAH_A_YA337A_',
#  '1MAH_A_DA74N_',
#  '1MAH_A_YA124Q_',
#  '1MAH_A_YA72N_',
#  '1MAH_A_WA286R_',
#  '1MAH_A_YA72N_YA124Q_',
#  '1MAH_A_YA124Q_WA286R_',
#  '1MAH_A_YA72N_WA286R_',
#  '1MAH_A_YA72N_YA124Q_WA286R_',
#  '1LFD_A_wt',
#  '1LFD_B_wt',
#  '1LFD_A_RA20A_',
#  '1LFD_A_SA22K_',
#  '1LFD_A_LA23K_',
#  '1LFD_A_NA27K_',
#  '1LFD_A_MA30K_',
#  '1LFD_A_KA32A_',
#  '1LFD_A_KA48A_',
#  '1LFD_A_DA51A_',
#  '1LFD_A_DA51K_',
#  '1LFD_A_KA52A_',
#  '1LFD_A_NA54K_',
#  '1LFD_A_LA55K_',
#  '1LFD_A_DA56A_',
#  '1LFD_A_EA57A_',
#  '1LFD_A_EA57K_',
#  '1LFD_A_DA58K_',
#  '1LFD_A_NA92K_',
#  '1LFD_A_YA93K_',
#  '1LFD_A_DA94K_',
#  '1LFD_A_MA30K_DA58K_',
#  '1LFD_A_MA30K_DA94K_',
#  '1LFD_A_MA30K_DA51K_DA58K_',
#  '1LFD_A_MA30K_DA51K_DA58K_DA94K_',
#  '1LFD_A_DA51K_DA56K_EA57K_',
#  '1LFD_A_DA58K_DA94K_',
#  '1KTZ_A_wt',
#  '1KTZ_B_wt',
#  '1KTZ_A_VA92I_',
#  '1KTZ_A_RA25K_',
#  '1KTZ_A_RA94K_',
#  '1KTZ_A_RA25A_',
#  '1KTZ_A_RA94A_',
#  '1KTZ_B_LB27A_',
#  '1KTZ_B_FB30A_',
#  '1KTZ_B_DB32A_',
#  '1KTZ_B_DB32N_',
#  '1KTZ_B_SB49A_',
#  '1KTZ_B_IB50A_',
#  '1KTZ_B_TB51A_',
#  '1KTZ_B_SB52A_',
#  '1KTZ_B_SB52L_',
#  '1KTZ_B_IB53A_',
#  '1KTZ_B_EB55A_',
#  '1KTZ_B_VB77A_',
#  '1KTZ_B_DB118A_',
#  '1KTZ_B_EB119A_',
#  '1KTZ_B_EB119Q_',
#  '1KTZ_B_NB47A_',
#  '1KTZ_B_VB62A_',
#  '1KTZ_B_EB75A_',
#  '1KTZ_B_HB79A_',
#  '1KTZ_B_FB110A_',
#  '1KTZ_B_MB112A_',
#  '1KTZ_B_IB125A_',
#  '1REW_AB_wt',
#  '1REW_C_wt',
#  '1REW_AB_DA30A_DB30A_',
#  '1REW_AB_WA31A_WB31A_',
#  '1REW_AB_DA30A_WA31A_DB30A_WB31A_',
#  '1REW_AB_FA49A_FB49A_',
#  '1REW_AB_PA50A_PB50A_',
#  '1REW_AB_FA49A_PA50A_FB49A_PB50A_',
#  '1REW_AB_HA39D_HB39D_',
#  '1REW_AB_SA88A_SB88A_',
#  '1REW_AB_LA100A_LB100A_',
#  '1REW_AB_HA39D_SA88A_HB39D_SB88A_',
#  '1REW_AB_HA39D_LA100A_HB39D_LB100A_',
#  '1REW_AB_AA34D_AB34D_',
#  '1REW_AB_DA53A_DB53A_',
#  '1REW_AB_EA109R_EB109R_',
#  '1REW_AB_DA30A_AA34D_DB30A_AB34D_',
#  '1REW_AB_AA34D_DA53A_AB34D_DB53A_',
#  '1REW_AB_DA53A_EA109R_DB53A_EB109R_',
#  '1REW_AB_WA28F_WB28F_',
#  '1REW_AB_DA53P_DB53P_',
#  '1REW_AB_SA69R_SB69R_',
#  '1REW_AB_YA103A_YB103A_',
#  '1REW_C_QC86A_',
#  '1REW_C_KC88R_SC90T_KC92I_AC93P_QC94H_LC95Q_TC98D_',
#  '2QJ9_AB_wt',
#  '2QJ9_C_wt',
#  '2QJ9_C_RC88K_TC90S_IC92K_PC93A_HC94Q_QC95L_SC98T_',
#  '1REW_C_KC88R_SC90T_KC92I_AC93P_QC94H_LC95Q_TC98D_AC74T_MC78L_KC79G_YC80L_',
#  '2QJ9_C_AC74T_MC78L_KC79G_YC80L_',
#  '2QJA_AB_wt',
#  '2QJA_C_wt',
#  '2QJA_C_TC74A_LC78M_GC79K_LC80Y_',
#  '2QJA_C_RC88K_TC90S_IC92K_PC93A_HC94Q_QC95L_SC98T_TC74A_LC78M_GC79K_LC80Y_',
#  '1REW_C_KC88R_SC90T_KC92I_AC93P_QC94H_LC95Q_TC98D_AC74T_MC78L_KC79G_YC80L_GC42H_DC46E_AC61T_IC62M_',
#  '2QJ9_C_AC74T_MC78L_KC79G_YC80L_GC42H_DC46E_AC61T_IC62M_',
#  '2QJA_C_GC42H_DC46E_AC61T_IC62M_',
#  '2QJB_AB_wt',
#  '2QJB_C_wt',
#  '2QJB_C_HC42G_EC46D_TC61A_MC62I_',
#  '2QJB_C_TC74A_LC78M_GC79K_LC80Y_HC42G_EC46D_TC61A_MC62I_',
#  '2QJB_C_RC88K_TC90S_IC92K_PC93A_HC94Q_QC95L_SC98T_TC74A_LC78M_GC79K_LC80Y_HC42G_EC46D_TC61A_MC62I_',
#  '3BK3_A_wt',
#  '3BK3_C_wt',
#  '3BK3_C_LC1A_',
#  '3BK3_C_LC1R_',
#  '3BK3_C_IC2A_',
#  '3BK3_C_IC2R_',
#  '3BK3_C_TC3P_',
#  '3BK3_C_TC5P_',
#  '3BK3_C_IC18A_',
#  '3BK3_C_IC18R_',
#  '3BK3_C_IC21A_',
#  '3BK3_C_IC21R_',
#  '3BK3_C_IC27A_',
#  '3BK3_C_IC27R_',
#  '3BK3_C_AC36R_',
#  '1XXM_A_wt',
#  '1XXM_C_wt',
#  '1XXM_A_AA104E_AA105Y_',
#  '1XXM_C_AC1074K_AC1142F_AC1143Y_',
#  '1S0W_A_wt',
#  '1S0W_C_wt',
#  '1S0W_C_AC1142F_',
#  '1JTG_A_wt',
#  '1JTG_B_wt',
#  '1JTG_A_GA238S_',
#  '1JTG_A_EA104K_',
#  '1JTG_B_DB49A_',
#  '1JTG_B_FB142A_',
#  '1JTG_A_SA235A_',
#  '1JTG_A_SA130A_',
#  '1JTG_A_SA235A_SA130A_',
#  '1JTG_A_RA243A_',
#  '1JTG_A_KA234A_',
#  '1JTG_A_RA243A_SA235A_',
#  '1JTG_A_RA243A_SA130A_',
#  '1JTG_A_SA235A_KA234A_',
#  '1JTG_A_KA234A_SA130A_',
#  '1JTG_A_RA243A_SA235A_SA130A_',
#  '1JTG_A_SA235A_SA130A_KA234A_',
#  '1JTG_A_RA243A_KA234A_',
#  '1JTG_A_RA243A_SA235A_KA234A_',
#  '1JTG_A_KA234A_SA130A_RA243A_',
#  '1JTG_A_KA234A_SA235A_SA130A_RA243A_',
#  '1JTG_B_KB74A_',
#  '1JTG_B_YB143A_',
#  '1JTG_B_KB74A_FB142A_',
#  '1JTG_B_KB74A_YB143A_',
#  '1JTG_B_FB142A_YB143A_',
#  '1JTG_B_KB74A_FB142A_YB143A_',
#  '1JTG_A_EA104A_',
#  '1JTG_A_YA105A_',
#  '1JTG_A_EA104A_YA105A_',
#  '1JTG_A_QA99A_',
#  '1JTG_A_NA100A_',
#  '1JTG_A_VA103A_',
#  '1JTG_A_PA107A_',
#  '1JTG_A_EA110A_',
#  '1JTG_A_MA129A_',
#  '1JTG_A_EA168A_',
#  '1JTG_A_VA216A_',
#  '1JTG_B_FB36A_',
#  '1JTG_B_HB41A_',
#  '1JTG_B_YB50A_',
#  '1JTG_B_YB53A_',
#  '1JTG_B_SB71A_',
#  '1JTG_B_WB112A_',
#  '1JTG_B_SB113A_',
#  '1JTG_B_HB148A_',
#  '1JTG_B_WB150A_',
#  '1JTG_B_RB160A_',
#  '1JTG_B_WB162A_',
#  '1JTG_B_SB113A_SB71A_',
#  '1JTG_B_SB71A_SB113A_',
#  '1JTG_B_TB32K_',
#  '1JTG_B_VB93K_',
#  '1JTG_B_TB140K_',
#  '1JTG_B_NB89K_',
#  '1JTG_B_DB163A_',
#  '1JTG_B_DB163K_',
#  '1JTG_B_TB140K_QB157K_',
#  '1JTG_B_VB165K_DB163K_NB89K_',
#  '1JTG_B_DB163K_DB135K_VB134K_',
#  '1JTG_B_VB165K_DB163K_DB135K_NB89K_',
#  '1HE8_A_wt',
#  '1HE8_B_wt',
#  '1HE8_A_KA223V_',
#  '1HE8_A_KA223V_RA226A_',
#  '1HE8_A_KA223V_KA234A_',
#  '1HE8_A_KA223V_DA238A_',
#  '1HE8_A_KA223V_KA254A_',
#  '1HE8_A_KA223V_KA256A_',
#  '1HE8_A_KA223V_DA260A_',
#  '1HE8_A_KA223V_EA267K_',
#  '1HE8_A_KA223V_EA919A_',
#  '1HE8_A_KA223V_EA919K_',
#  '1H9D_A_wt',
#  '1H9D_B_wt',
#  '1H9D_B_RB3A_',
#  '1H9D_B_VB4A_',
#  '1H9D_B_GB61A_',
#  '1H9D_B_QB67A_',
#  '1H9D_B_LB103A_',
#  '1H9D_B_NB104A_',
#  '1GRN_A_wt',
#  '1GRN_B_wt',
#  '1GRN_A_DA38E_',
#  '1GL1_A_wt',
#  '1GL1_I_wt',
#  '1GL1_I_LI30V_',
#  '1GL1_I_KI31M_AI32G_',
#  '1GL0_E_wt',
#  '1GL0_I_wt',
#  '1GL0_I_MI30K_',
#  '1GL0_I_MI30K_LI29R_',
#  '1FFW_A_wt',
#  '1FFW_B_wt',
#  '1FFW_A_DA13K_',
#  '1FFW_A_TA87I_',
#  '1FFW_A_AA90V_',
#  '1FFW_A_EA93K_',
#  '1FFW_A_YA106W_',
#  '1FFW_A_VA108M_',
#  '1FFW_A_FA111V_',
#  '1FFW_A_TA112I_',
#  '1FFW_A_EA117K_',
#  '1FFW_B_EB171A_',
#  '1FFW_B_EB178A_',
#  '1FFW_B_HB181A_',
#  '1FFW_B_DB202A_',
#  '1FFW_B_DB207A_',
#  '1FFW_B_CB213A_',
#  '1FFW_B_FB214A_',
#  '1FFW_B_IB216A_',
#  '1FC2_C_wt',
#  '1FC2_D_wt',
#  '1FC2_C_YC133W_',
#  '1FC2_C_IC135W_',
#  '1FC2_C_FC149W_',
#  '1FC2_C_LC163W_',
#  '1FC2_C_LC136D_',
#  '1FC2_C_NC147A_',
#  '1FC2_C_FC149A_',
#  '1FC2_C_IC150A_',
#  '1FC2_C_KC154A_',
#  '1EAW_A_wt',
#  '1EAW_B_wt',
#  '1EAW_A_QA38A_',
#  '1EAW_A_IA41A_',
#  '1EAW_A_IA60A_',
#  '1EAW_A_DA60aA_',
#  '1EAW_A_DA60bA_',
#  '1EAW_A_RA60cA_',
#  '1EAW_A_FA60eA_',
#  '1EAW_A_RA60fA_',
#  '1EAW_A_YA60gA_',
#  '1EAW_A_RA87A_',
#  '1EAW_A_FA94A_',
#  '1EAW_A_NA95A_',
#  '1EAW_A_DA96A_',
#  '1EAW_A_FA97A_',
#  '1EAW_A_TA98A_',
#  '1EAW_A_HA143A_',
#  '1EAW_A_QA145A_',
#  '1EAW_A_YA146A_',
#  '1EAW_A_TA150A_',
#  '1EAW_A_LA153A_',
#  '1EAW_A_EA169A_',
#  '1EAW_A_QA174A_',
#  '1EAW_A_QA175A_',
#  '1EAW_A_DA217A_',
#  '1EAW_A_QA221aA_',
#  '1EAW_A_RA222A_',
#  '1EAW_A_KA224A_',
#  '3BN9_B_wt',
#  '3BN9_CD_wt',
#  '3BN9_B_QB38A_',
#  '3BN9_B_IB41A_',
#  '3BN9_B_IB60A_',
#  '3BN9_B_DB60aA_',
#  '3BN9_B_DB60bA_',
#  '3BN9_B_RB60cA_',
#  '3BN9_B_FB60eA_',
#  '3BN9_B_RB60fA_',
#  '3BN9_B_YB60gA_',
#  '3BN9_B_RB87A_',
#  '3BN9_B_FB94A_',
#  '3BN9_B_NB95A_',
#  '3BN9_B_TB98A_',
#  '3BN9_B_HB143A_',
#  '3BN9_B_QB145A_',
#  '3BN9_B_YB146A_',
#  '3BN9_B_TB150A_',
#  '3BN9_B_LB153A_',
#  '3BN9_B_EB169A_',
#  '3BN9_B_QB174A_',
#  '3BN9_B_QB175A_',
#  '3BN9_B_DB217A_',
#  '3BN9_B_QB221aA_',
#  '3BN9_B_RB222A_',
#  '3BN9_B_KB224A_',
#  '3NPS_A_wt',
#  '3NPS_BC_wt',
#  '3NPS_A_QA38A_',
#  '3NPS_A_IA41A_',
#  '3NPS_A_IA60A_',
#  '3NPS_A_DA60aA_',
#  '3NPS_A_DA60bA_',
#  '3NPS_A_RA60cA_',
#  '3NPS_A_FA60eA_',
#  '3NPS_A_RA60fA_',
#  '3NPS_A_YA60gA_',
#  ...]

# %%
multiplied_vectors = pd.DataFrame({'Protein1': pd.Series([], dtype='str'),\
                                   'Protein2': pd.Series([], dtype='str'),\
                                   'Vector': pd.Series([], dtype='object')}) 

rep_prot_list = list(seqvec_skempi_vectors_df['PDB_ID'])
for index,row in tqdm.tqdm(ppi_affinity_df.iterrows()):
    if row['Protein1'] in rep_prot_list and row['Protein2'] in rep_prot_list:
        vec1 = list(seqvec_skempi_vectors_df[seqvec_skempi_vectors_df['PDB_ID']\
                                             == row['Protein1']]['Vector'])[0]
        vec2 = list(seqvec_skempi_vectors_df[seqvec_skempi_vectors_df['PDB_ID']\
                                             == row['Protein2']]['Vector'])[0]
        multiplied_vec = np.multiply(vec1,vec2)
        multiplied_vectors = multiplied_vectors.\
            append({'Protein1':row['Protein1'], 'Protein2':row['Protein2'],\
                    'Vector':multiplied_vec},ignore_index = True)
# Out:
# 2950it [00:06, 434.19it/s]

# %%
multiplied_vectors
# Out:
#        Protein1                      Protein2  \
# 0     1A22_A_wt                1A22_B_CB308A_
# 1     1A22_A_wt                1A22_B_CB322A_
# 2     1A22_A_wt  1A22_B_DB319A_EB320A_KB321A_
# 3     1A22_A_wt                1A22_B_DB326A_
# 4     1A22_A_wt                1A22_B_DB332A_
# ...         ...                           ...
# 2945  4CPA_A_wt                 4CPA_I_VI38I_
# 2946  4CPA_A_wt                 4CPA_I_VI38L_
# 2947  4CPA_A_wt                     4CPA_I_wt
# 2948  4CPA_A_wt                 4CPA_I_YI37F_
# 2949  4CPA_A_wt                 4CPA_I_YI37G_
#
#                                                  Vector
# 0     [0.19975081255073318, 0.11925270593096915, 0.0...
# 1     [0.19975081255073318, 0.11925270593096915, 0.0...
# 2     [0.19975081255073318, 0.11925270593096915, 0.0...
# 3     [0.19975081255073318, 0.11925270593096915, 0.0...
# 4     [0.19975081255073318, 0.11925270593096915, 0.0...
# ...                                                 ...
# 2945  [0.19975081255073318, 0.11925270593096915, 0.0...
# 2946  [0.19975081255073318, 0.11925270593096915, 0.0...
# 2947  [0.19975081255073318, 0.11925270593096915, 0.0...
# 2948  [0.19975081255073318, 0.11925270593096915, 0.0...
# 2949  [0.19975081255073318, 0.11925270593096915, 0.0...
#
# [2950 rows x 3 columns]

# %%
def calc_train_error(X_train, y_train, model):
    '''returns in-sample error for already fit model.'''
    predictions = model.predict(X_train)
    mse = mean_squared_error(y_train, predictions)
    mae = mean_absolute_error(y_train, predictions)
    corr = scipy.stats.pearsonr(y_train, predictions)
    return mse,mae,corr
    
def calc_validation_error(X_test, y_test, model):
    '''returns out-of-sample error for already fit model.'''
    predictions = model.predict(X_test)
    mse = mean_squared_error(y_test, predictions)
    mae = mean_absolute_error(y_test, predictions)
    corr = scipy.stats.pearsonr(y_test, predictions)
    return mse,mae,corr
    
def calc_metrics(X_train, y_train, X_test, y_test, model):
    '''fits model and returns the metrics for in-sample error and out-of-sample error'''
    model.fit(X_train, y_train)
    train_mse_error,train_mae_error,train_corr = calc_train_error(X_train, y_train, model)
    val_mse_error,val_mae_error,val_corr = calc_validation_error(X_test, y_test, model)
    return train_mse_error, val_mse_error, train_mae_error, val_mae_error,train_corr,val_corr

# %%
y_train = [0.45462982, 0.45462982, 0.4391372 , 0.5315291 , 0.46772246,0.49276013]

# %%
l = [1,2,3]

# %%
def report_results(
    train_mse_error_list,
    validation_mse_error_list,
    train_mae_error_list,
    validation_mae_error_list,
    train_corr_list,
    validation_corr_list,
    train_corr_pval_list,
    validation_corr_pval_list,
):
    result_df = pd.DataFrame(
        {
            "train_mse_error": round(np.mean(train_mse_error_list) * 100, 4),
            "train_mse_std": round(np.std(train_mse_error_list) * 100, 4),
            "val_mse_error": round(np.mean(validation_mse_error_list) * 100, 4),
            "val_mse_std": round(np.std(validation_mse_error_list) * 100, 4),
            "train_mae_error": round(np.mean(train_mae_error_list) * 100, 4),
            "train_mae_std": round(np.std(train_mae_error_list) * 100, 4),
            "val_mae_error": round(np.mean(validation_mae_error_list) * 100, 4),
            "val_mae_std": round(np.std(validation_mae_error_list) * 100, 4),
            "train_corr": round(np.mean(train_corr_list), 4),
            "train_corr_pval": round(np.mean(train_corr_pval_list), 4),
            "validation_corr": round(np.mean(validation_corr_list), 4),
            "validation_corr_pval": round(np.mean(validation_corr_pval_list), 4),
        },
        index=[0],
    )

    result_detail_df = pd.DataFrame(
        {
            "train_mse_errors": list(np.multiply(train_mse_error_list, 100)),
            "val_mse_errors": list(np.multiply(validation_mse_error_list, 100)),
            "train_mae_errors": list(np.multiply(train_mae_error_list, 100)),
            "val_mae_errors": list(np.multiply(validation_mae_error_list, 100)),
            "train_corrs": list(np.multiply(train_corr_list, 100)),
            "train_corr_pvals": list(np.multiply(train_corr_pval_list, 100)),
            "validation_corr": list(np.multiply(validation_corr_list, 100)),
            "validation_corr_pval": list(np.multiply(validation_corr_pval_list, 100)),
        },
        index=range(len(train_mse_error_list)),
    )
    return result_df, result_detail_df

# %%
def predictAffinityWithModel(regressor_model):
    K = 10
    kf = KFold(n_splits=K, shuffle=True, random_state=42)

    train_mse_error_list = []
    validation_mse_error_list = []
    train_mae_error_list = []
    validation_mae_error_list = []
    train_corr_list = []
    validation_corr_list = []
    train_corr_pval_list = []
    validation_corr_pval_list = []

    data = np.array(np.asarray(multiplied_vectors["Vector"].tolist()), dtype=float)
    ppi_affinity_filtered_df = ppi_affinity_df\
        [ppi_affinity_df['Protein1'].isin(multiplied_vectors['Protein1']) & \
         ppi_affinity_df['Protein2'].isin(multiplied_vectors['Protein2']) ]
    target = np.array(ppi_affinity_filtered_df["Affinity"])
    scaler = MinMaxScaler()
    scaler.fit(target.reshape(-1, 1))
    target = scaler.transform(target.reshape(-1, 1))[:, 0]
    for train_index, val_index in tqdm.tqdm(kf.split(data, target), total=K):

        # split data
        X_train, X_val = data[train_index], data[val_index]
        y_train, y_val = target[train_index], target[val_index]

        # instantiate model
        reg = regressor_model #linear_model.BayesianRidge()

        # calculate error_list
        (
            train_mse_error,
            val_mse_error,
            train_mae_error,
            val_mae_error,
            train_corr,
            val_corr,
        ) = calc_metrics(X_train, y_train, X_val, y_val, reg)

        # append to appropriate list
        train_mse_error_list.append(train_mse_error)
        validation_mse_error_list.append(val_mse_error)

        train_mae_error_list.append(train_mae_error)
        validation_mae_error_list.append(val_mae_error)

        train_corr_list.append(train_corr[0])
        validation_corr_list.append(val_corr[0])

        train_corr_pval_list.append(train_corr[1])
        validation_corr_pval_list.append(val_corr[1])

    return report_results(
        train_mse_error_list,
        validation_mse_error_list,
        train_mae_error_list,
        validation_mae_error_list,
        train_corr_list,
        validation_corr_list,
        train_corr_pval_list,
        validation_corr_pval_list,
    )

# %%
model = linear_model.BayesianRidge()
result_df, result_detail_df = predictAffinityWithModel(model)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
#  10%|█         | 1/10 [00:01<00:09,  1.10s/it]/media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
#  20%|██        | 2/10 [00:02<00:08,  1.06s/it]/media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
#  30%|███       | 3/10 [00:03<00:07,  1.05s/it]/media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
#  40%|████      | 4/10 [00:04<00:06,  1.03s/it]/media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
#  50%|█████     | 5/10 [00:05<00:05,  1.06s/it]/media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
#  60%|██████    | 6/10 [00:06<00:04,  1.02s/it]/media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
#  70%|███████   | 7/10 [00:07<00:03,  1.01s/it]/media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
#  80%|████████  | 8/10 [00:08<00:02,  1.02s/it]/media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
#  90%|█████████ | 9/10 [00:09<00:01,  1.01s/it]/media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /media/DATA/serbulent/conda_envs/skempi/lib/python3.9/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]

# %%
result_df
# Out:
#    train_mse_error  train_mse_std  val_mse_error  val_mse_std  \
# 0           2.3458         0.0115         2.3474       0.1029
#
#    train_mae_error  train_mae_std  val_mae_error  val_mae_std  train_corr  \
# 0           12.027         0.0415        12.0305       0.3593         NaN
#
#    train_corr_pval  validation_corr  validation_corr_pval
# 0              NaN              NaN                   NaN

# %%
result_detail_df
# Out:
#    train_mse_errors  val_mse_errors  train_mae_errors  val_mae_errors  \
# 0          1.757003        1.756543         10.130397       10.231082
# 1          1.746865        1.877006         10.123038       10.339209
# 2          1.756751        1.756783         10.155731        9.883432
# 3          1.737997        1.938557         10.065078       10.739856
# 4          1.762882        1.714857         10.171091        9.905500
# 5          1.784332        1.498729         10.212101        9.479030
# 6          1.759358        1.738988         10.160627       10.167630
# 7          1.732155        1.984052         10.065873       10.826505
# 8          1.751489        1.810791         10.117778       10.267877
# 9          1.749020        1.824198         10.107870       10.427031
#
#    train_corrs  train_corr_pvals  validation_corr  validation_corr_pval
# 0    49.382482     3.110485e-160        45.485794          2.031100e-14
# 1    48.563335     3.480839e-154        51.844779          1.260535e-19
# 2    49.078154     5.005101e-158        49.056762          3.785524e-17
# 3    49.042301     9.226276e-158        48.403158          1.293217e-16
# 4    49.294463     1.230775e-159        45.819260          1.296181e-14
# 5    48.722592     2.087392e-155        53.640803          3.133354e-21
# 6    48.363621     8.584089e-153        54.314889          6.946794e-22
# 7    50.110435     8.212809e-166        39.713834          1.648531e-10
# 8    48.990581     2.226540e-157        49.134132          3.267446e-17
# 9    50.002650     5.494180e-165        39.833445          1.394508e-10

# %%
model = RandomForestRegressor(n_estimators=100,n_jobs=multiprocessing.cpu_count(),random_state=42)
result_df, result_detail_df = predictAffinityWithModel(model)
# Out:
# 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]

# %%
result_detail_df
# Out:
#    train_mse_errors  val_mse_errors  train_mae_errors  val_mae_errors  \
# 0          0.067559        0.469054          1.827186        4.914937
# 1          0.068395        0.442329          1.820982        4.852125
# 2          0.065270        0.505735          1.813709        4.870343
# 3          0.070137        0.495580          1.845628        5.004709
# 4          0.069142        0.565113          1.845183        5.176936
# 5          0.070254        0.447954          1.837370        4.851087
# 6          0.067307        0.396547          1.835443        4.500032
# 7          0.068440        0.552359          1.837464        5.406611
# 8          0.066760        0.489242          1.810191        4.936337
# 9          0.069163        0.477334          1.845142        4.692167
#
#    train_corrs  train_corr_pvals  validation_corr  validation_corr_pval
# 0    98.750650               0.0        89.008526          1.200906e-99
# 1    98.723898               0.0        91.032039         6.984970e-112
# 2    98.802618               0.0        88.465894          1.938489e-96
# 3    98.677877               0.0        89.728680         2.378498e-103
# 4    98.722119               0.0        85.976947          6.406394e-85
# 5    98.717402               0.0        88.603990          3.732097e-97
# 6    98.752498               0.0        91.667712         6.154616e-116
# 7    98.728358               0.0        87.353473          5.457404e-91
# 8    98.766592               0.0        89.499094         4.986167e-102
# 9    98.721272               0.0        88.398869          4.280078e-96

# %%
## For K = 10

# %%
model = linear_model.BayesianRidge()
predictAffinityWithModel(model)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 69.77it/s]
# (   train_mse_error  train_mse_std  val_mse_error  val_mse_std  \
#  0           1.7538         0.0136         1.7901       0.1281
#
#     train_mae_error  train_mae_std  val_mae_error  val_mae_std  train_corr  \
#  0           10.131         0.0436        10.2267       0.3822      0.4916
#
#     train_corr_pval  validation_corr  validation_corr_pval
#  0              0.0           0.4772                   0.0  ,
#     train_mse_errors  val_mse_errors  train_mae_errors  val_mae_errors  \
#  0          1.757003        1.756543         10.130397       10.231082
#  1          1.746865        1.877006         10.123038       10.339209
#  2          1.756751        1.756783         10.155731        9.883432
#  3          1.737997        1.938557         10.065078       10.739856
#  4          1.762882        1.714857         10.171091        9.905500
#  5          1.784332        1.498729         10.212101        9.479030
#  6          1.759358        1.738988         10.160627       10.167630
#  7          1.732155        1.984052         10.065873       10.826505
#  8          1.751489        1.810791         10.117778       10.267877
#  9          1.749020        1.824198         10.107870       10.427031
#
#     train_corrs  train_corr_pvals  validation_corr  validation_corr_pval
#  0    49.382482     3.110485e-160        45.485794          2.031100e-14
#  1    48.563335     3.480839e-154        51.844779          1.260535e-19
#  2    49.078154     5.005101e-158        49.056762          3.785524e-17
#  3    49.042301     9.226276e-158        48.403158          1.293217e-16
#  4    49.294463     1.230775e-159        45.819260          1.296181e-14
#  5    48.722592     2.087392e-155        53.640803          3.133354e-21
#  6    48.363621     8.584089e-153        54.314889          6.946794e-22
#  7    50.110435     8.212809e-166        39.713834          1.648531e-10
#  8    48.990581     2.226540e-157        49.134132          3.267446e-17
#  9    50.002650     5.494180e-165        39.833445          1.394508e-10  )

# %%
model = RandomForestRegressor(n_estimators=100,n_jobs=multiprocessing.cpu_count(),random_state=42)
predictAffinityWithModel(model)
# Out:
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# (   train_mse_error  train_mse_std  val_mse_error  val_mse_std  \
#  0           0.0682         0.0015         0.4841       0.0478
#
#     train_mae_error  train_mae_std  val_mae_error  val_mae_std  train_corr  \
#  0           1.8318         0.0125         4.9205       0.2346      0.9874
#
#     train_corr_pval  validation_corr  validation_corr_pval
#  0              0.0           0.8897                   0.0  ,
#     train_mse_errors  val_mse_errors  train_mae_errors  val_mae_errors  \
#  0          0.067559        0.469054          1.827186        4.914937
#  1          0.068395        0.442329          1.820982        4.852125
#  2          0.065270        0.505735          1.813709        4.870343
#  3          0.070137        0.495580          1.845628        5.004709
#  4          0.069142        0.565113          1.845183        5.176936
#  5          0.070254        0.447954          1.837370        4.851087
#  6          0.067307        0.396547          1.835443        4.500032
#  7          0.068440        0.552359          1.837464        5.406611
#  8          0.066760        0.489242          1.810191        4.936337
#  9          0.069163        0.477334          1.845142        4.692167
#
#     train_corrs  train_corr_pvals  validation_corr  validation_corr_pval
#  0    98.750650               0.0        89.008526          1.200906e-99
#  1    98.723898               0.0        91.032039         6.984970e-112
#  2    98.802618               0.0        88.465894          1.938489e-96
#  3    98.677877               0.0        89.728680         2.378498e-103
#  4    98.722119               0.0        85.976947          6.406394e-85
#  5    98.717402               0.0        88.603990          3.732097e-97
#  6    98.752498               0.0        91.667712         6.154616e-116
#  7    98.728358               0.0        87.353473          5.457404e-91
#  8    98.766592               0.0        89.499094         4.986167e-102
#  9    98.721272               0.0        88.398869          4.280078e-96  )

# %%
model = RandomForestRegressor(n_estimators=50,n_jobs=multiprocessing.cpu_count(),random_state=42,max_depth=15)
predictAffinityWithModel(model)
# Out:
# 100%|██████████| 10/10 [00:04<00:00,  2.24it/s]
# (   train_mse_error  train_mse_std  val_mse_error  val_mse_std  \
#  0           0.1102         0.0031         0.4965       0.0468
#
#     train_mae_error  train_mae_std  val_mae_error  val_mae_std  train_corr  \
#  0            2.415         0.0429         5.0266       0.2235      0.9787
#
#     train_corr_pval  validation_corr  validation_corr_pval
#  0              0.0           0.8871                   0.0  ,
#     train_mse_errors  val_mse_errors  train_mae_errors  val_mae_errors  \
#  0          0.105495        0.488541          2.348009        5.046114
#  1          0.107847        0.437135          2.351157        4.893935
#  2          0.107709        0.528474          2.411048        4.992903
#  3          0.111220        0.517198          2.412659        5.107428
#  4          0.107776        0.566480          2.405104        5.271641
#  5          0.113054        0.466815          2.433438        4.961250
#  6          0.115370        0.408429          2.486269        4.595815
#  7          0.108642        0.554147          2.405139        5.479257
#  8          0.110006        0.501459          2.417671        5.029810
#  9          0.114444        0.496384          2.479860        4.888061
#
#     train_corrs  train_corr_pvals  validation_corr  validation_corr_pval
#  0    97.942228               0.0        88.501231          5.922240e-97
#  1    97.900993               0.0        91.162708         9.041289e-113
#  2    97.921319               0.0        87.901702          1.313680e-93
#  3    97.811484               0.0        89.240423         1.413866e-100
#  4    97.932331               0.0        85.972394          6.692715e-85
#  5    97.831585               0.0        88.110957          1.216999e-94
#  6    97.771445               0.0        91.469160         1.632082e-114
#  7    97.888648               0.0        87.359359          5.123030e-91
#  8    97.868411               0.0        89.325429         4.755132e-101
#  9    97.799493               0.0        88.009092          3.896372e-94  )

# %%
model = RandomForestRegressor(n_estimators=30,n_jobs=multiprocessing.cpu_count(),random_state=42,max_depth=12)
predictAffinityWithModel(model)
# Out:
# 100%|██████████| 10/10 [00:02<00:00,  3.51it/s]
# (   train_mse_error  train_mse_std  val_mse_error  val_mse_std  \
#  0           0.1797         0.0062         0.5417       0.0451
#
#     train_mae_error  train_mae_std  val_mae_error  val_mae_std  train_corr  \
#  0            3.099         0.0559         5.3262       0.2043       0.964
#
#     train_corr_pval  validation_corr  validation_corr_pval
#  0              0.0           0.8762                   0.0  ,
#     train_mse_errors  val_mse_errors  train_mae_errors  val_mae_errors  \
#  0          0.176487        0.520168          3.044406        5.259202
#  1          0.173485        0.483121          3.029979        5.242784
#  2          0.179656        0.561943          3.129318        5.257106
#  3          0.179908        0.569328          3.090562        5.394189
#  4          0.167011        0.587457          2.995861        5.478064
#  5          0.191120        0.539383          3.181767        5.325848
#  6          0.184822        0.449026          3.155295        4.939944
#  7          0.182685        0.604226          3.130084        5.780024
#  8          0.179911        0.567654          3.104868        5.381985
#  9          0.181736        0.535083          3.127407        5.202742
#
#     train_corrs  train_corr_pvals  validation_corr  validation_corr_pval
#  0    96.440472               0.0        87.777141          2.535836e-93
#  1    96.523107               0.0        90.179844         2.092812e-106
#  2    96.424292               0.0        87.092302          8.745899e-90
#  3    96.325567               0.0        88.092407          1.505435e-94
#  4    96.687799               0.0        85.421944          1.183702e-82
#  5    96.227797               0.0        86.127381          1.497664e-85
#  6    96.274692               0.0        90.604608         1.073184e-108
#  7    96.338097               0.0        86.120315          1.604093e-85
#  8    96.393372               0.0        87.759787          6.432167e-93
#  9    96.348295               0.0        87.058899          1.241664e-89  )

# %%
model = RandomForestRegressor(n_estimators=30,n_jobs=multiprocessing.cpu_count(),random_state=42,max_depth=10)
predictAffinityWithModel(model)

# %%
model = RandomForestRegressor(n_estimators=15,n_jobs=multiprocessing.cpu_count(),random_state=42,max_depth=10)
predictAffinityWithModel(model)

# %%
np.min([i.tree_.max_depth for i in model.estimators_])
