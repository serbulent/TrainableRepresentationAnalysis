# %%
import glob
import os
import scipy
import math
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
import statsmodels.stats.multitest as mt
from pathlib import Path
from scipy.stats import ttest_rel
from scipy.stats import shapiro

# %%
mse_list = []
mae_list = []
representation_name_list = []
for path in Path("/media/DATA/serbulent/Code/Thesis/ReviewPaper/generalized_representation_benchmark/results/")\
.glob("Affinit_prediction_skempiv1_*_detail.csv"):
    #print(path)
    representation_name_list.append(str(path).split("skempiv1_")[1].split("_detail.csv")[0])
    mse_list.append(pd.read_csv(path)['val_mse_errors'])
    mae_list.append(pd.read_csv(path)['val_mae_errors'])
    
df_mse = pd.concat(mse_list, axis=1)
df_mse.columns = representation_name_list
#Sorting columns by their mean value
df_mse = df_mse.reindex(df_mse.mean().sort_values().index, axis=1)

df_mae = pd.concat(mae_list, axis=1)
df_mae.columns = representation_name_list
#Sorting columns by their mean value
df_mae = df_mae.reindex(df_mae.mean().sort_values().index, axis=1)

# %%
df_mse
# Out:
#      ALBERT     ESMB1    SEQVEC  BERT-BFD        T5     XLNET   CPCPROT  \
# 0  0.363818  0.450163  0.485027  0.444817  0.542026  0.575570  0.613292
# 1  0.414565  0.493169  0.589129  0.611387  0.537978  0.682961  0.738369
# 2  0.422572  0.434206  0.538995  0.926363  0.527603  0.569832  0.854581
# 3  0.418076  0.621966  0.600896  0.566967  0.587362  0.712379  0.808556
# 4  0.376907  0.476562  0.511827  0.486599  0.531136  0.587876  0.663005
# 5  0.385243  0.488588  0.482960  0.529628  0.504556  0.512663  0.621654
# 6  0.533704  0.435311  0.587326  0.671858  1.043043  0.695626  0.803881
# 7  0.515289  0.549829  0.586660  0.555272  0.518099  0.655713  0.826819
# 8  0.316215  0.414722  0.498666  0.463734  0.657308  0.520614  0.664550
# 9  0.436316  0.463862  0.449098  0.479161  0.585781  0.554477  0.704288
#
#      UNIREP      KSEP   PROTVEC  LEARNED-VEC     APAAC       AAC      PFAM  \
# 0  0.660293  0.819674  0.945078     1.016695  1.756543  1.683668  2.108073
# 1  0.762166  1.074306  1.107979     1.161348  1.877006  1.948253  2.369755
# 2  0.686010  1.074676  1.184138     1.279863  1.756783  1.944204  2.273111
# 3  0.732935  1.072209  1.305883     1.227308  1.938557  1.930600  2.424406
# 4  0.683952  0.846457  1.094767     1.171091  1.714857  1.696047  2.281235
# 5  0.658096  0.989920  1.077726     1.047167  1.498729  1.648721  2.058992
# 6  0.712041  0.856228  1.134837     1.250117  1.738988  1.854286  2.254950
# 7  0.888054  1.137318  1.158530     1.253739  1.984052  1.839930  2.227672
# 8  0.761072  0.981106  1.154163     1.133077  1.810791  2.013785  2.342703
# 9  0.776349  0.853148  1.177525     1.307355  1.824198  1.918340  2.237945
#
#    BERT-PFAM
# 0   2.203647
# 1   2.425253
# 2   2.369533
# 3   2.511810
# 4   2.343284
# 5   2.189843
# 6   2.470940
# 7   2.267294
# 8   2.397333
# 9   2.295489

# %%
def check_for_normality(go_pred_signinificance_score_df):
    for col in go_pred_signinificance_score_df:
        stat, p = shapiro(go_pred_signinificance_score_df[col])
        # interpret
        alpha = 0.05
        if p < alpha:
            print('Data does not drawn from a Normal distribution (reject H0) for ' + col)
            print('Statistics=%.3f, p=%.3f' % (stat, p))

# %%
check_for_normality(df_mae)
# Out:
# Data does not drawn from a Normal distribution (reject H0) for PFAM
# Statistics=0.802, p=0.015

# %%
check_for_normality(df_mse)
# Out:
# Data does not drawn from a Normal distribution (reject H0) for BERT-BFD
# Statistics=0.806, p=0.017
# Data does not drawn from a Normal distribution (reject H0) for T5
# Statistics=0.602, p=0.000

# %%
scipy.stats.wilcoxon(df_mse['ALBERT'], df_mse['PFAM'],zero_method='zsplit')
# Out:
# WilcoxonResult(statistic=0.0, pvalue=0.001953125)

# %%
scipy.stats.wilcoxon(df_mse['ALBERT'], df_mse['SEQVEC'],zero_method='zsplit')
# Out:
# WilcoxonResult(statistic=0.0, pvalue=0.001953125)

# %%
scipy.stats.wilcoxon(df_mae['ALBERT'], df_mae['PFAM'],zero_method='zsplit')
# Out:
# WilcoxonResult(statistic=0.0, pvalue=0.001953125)

# %%
scipy.stats.wilcoxon(df_mae['ALBERT'], df_mae['SEQVEC'],zero_method='zsplit')
# Out:
# WilcoxonResult(statistic=0.0, pvalue=0.001953125)

# %%
ttest_rel(df_mse['ALBERT'], df_mse['PFAM'])
# Out:
# Ttest_relResult(statistic=-45.26877170213428, pvalue=6.26464552949668e-12)

# %%
ttest_rel(df_mse['ALBERT'], df_mse['SEQVEC'])
# Out:
# Ttest_relResult(statistic=-6.334666834470753, pvalue=0.00013530681621252668)

# %%
list(df_mse['ALBERT'])
# Out:
# [0.3638181205766389,
#  0.4145647246062643,
#  0.4225723542059362,
#  0.4180755689420302,
#  0.3769070687465099,
#  0.3852427891764156,
#  0.5337044027341763,
#  0.5152892577275208,
#  0.3162150639244056,
#  0.4363157506928524]

# %%
list(df_mse['SEQVEC'])
# Out:
# [0.4850268762927039,
#  0.5891293710389106,
#  0.5389950466321576,
#  0.6008960241488368,
#  0.5118265717285728,
#  0.4829595185286985,
#  0.5873263197580205,
#  0.5866599413281838,
#  0.4986661814715105,
#  0.4490983245787546]

# %%
list(df_mse['PFAM'])
# Out:
# [2.1080725198514347,
#  2.369754712761041,
#  2.2731113271623857,
#  2.4244058851458106,
#  2.2812349641007827,
#  2.058992245277642,
#  2.2549504748938407,
#  2.227671872078743,
#  2.3427025287118317,
#  2.237944953316925]

# %%
def nan_to_zero(x):
    if math.isnan(x):
        return 0
    else:
        return x

def calculate_q_vals(pred_score_table):
    tTest_pvalue_list = []
    for model1 in pred_score_table:
        for model2 in pred_score_table:
            print(model1,model2)
            t_result =scipy.stats.wilcoxon(pred_score_table[model1], pred_score_table[model2],zero_method='zsplit')
            tTest_pvalue_list.append(t_result.pvalue)

    tTest_pvalue_list = [nan_to_zero(p_val) for p_val in tTest_pvalue_list]
    #multiple test correction using  Benjamini/Hochberg
    q_vals = tTest_pvalue_list #mt.multipletests(tTest_pvalue_list, method='fdr_bh')[1]

    #convert q value list to dataframe
    model_number = len(pred_score_table.columns)
    chunks = [q_vals[x:x+model_number] for x in range(0, len(q_vals), model_number)]
    qval_df = pd.DataFrame(chunks,columns=pred_score_table.columns)

    qval_df.set_index(pred_score_table.columns, inplace=True)
    return qval_df

# %%
mae_qval_df = calculate_q_vals(df_mse)
mae_qval_df
# Out:
# ALBERT ALBERT
# ALBERT ESMB1
# ALBERT SEQVEC
# ALBERT BERT-BFD
# ALBERT T5
# ALBERT XLNET
# ALBERT CPCPROT
# ALBERT UNIREP
# ALBERT KSEP
# ALBERT PROTVEC
# ALBERT LEARNED-VEC
# ALBERT APAAC
# ALBERT AAC
# ALBERT PFAM
# ALBERT BERT-PFAM
# ESMB1 ALBERT
# ESMB1 ESMB1
# ESMB1 SEQVEC
# ESMB1 BERT-BFD
# ESMB1 T5
# ESMB1 XLNET
# ESMB1 CPCPROT
# ESMB1 UNIREP
# ESMB1 KSEP
# ESMB1 PROTVEC
# ESMB1 LEARNED-VEC
# ESMB1 APAAC
# ESMB1 AAC
# ESMB1 PFAM
# ESMB1 BERT-PFAM
# SEQVEC ALBERT
# SEQVEC ESMB1
# SEQVEC SEQVEC
# SEQVEC BERT-BFD
# SEQVEC T5
# SEQVEC XLNET
# SEQVEC CPCPROT
# SEQVEC UNIREP
# SEQVEC KSEP
# SEQVEC PROTVEC
# SEQVEC LEARNED-VEC
# SEQVEC APAAC
# SEQVEC AAC
# SEQVEC PFAM
# SEQVEC BERT-PFAM
# BERT-BFD ALBERT
# BERT-BFD ESMB1
# BERT-BFD SEQVEC
# BERT-BFD BERT-BFD
# BERT-BFD T5
# BERT-BFD XLNET
# BERT-BFD CPCPROT
# BERT-BFD UNIREP
# BERT-BFD KSEP
# BERT-BFD PROTVEC
# BERT-BFD LEARNED-VEC
# BERT-BFD APAAC
# BERT-BFD AAC
# BERT-BFD PFAM
# BERT-BFD BERT-PFAM
# T5 ALBERT
# T5 ESMB1
# T5 SEQVEC
# T5 BERT-BFD
# T5 T5
# T5 XLNET
# T5 CPCPROT
# T5 UNIREP
# T5 KSEP
# T5 PROTVEC
# T5 LEARNED-VEC
# T5 APAAC
# T5 AAC
# T5 PFAM
# T5 BERT-PFAM
# XLNET ALBERT
# XLNET ESMB1
# XLNET SEQVEC
# XLNET BERT-BFD
# XLNET T5
# XLNET XLNET
# XLNET CPCPROT
# XLNET UNIREP
# XLNET KSEP
# XLNET PROTVEC
# XLNET LEARNED-VEC
# XLNET APAAC
# XLNET AAC
# XLNET PFAM
# XLNET BERT-PFAM
# CPCPROT ALBERT
# CPCPROT ESMB1
# CPCPROT SEQVEC
# CPCPROT BERT-BFD
# CPCPROT T5
# CPCPROT XLNET
# CPCPROT CPCPROT
# CPCPROT UNIREP
# CPCPROT KSEP
# CPCPROT PROTVEC
# CPCPROT LEARNED-VEC
# CPCPROT APAAC
# CPCPROT AAC
# CPCPROT PFAM
# CPCPROT BERT-PFAM
# UNIREP ALBERT
# UNIREP ESMB1
# UNIREP SEQVEC
# UNIREP BERT-BFD
# UNIREP T5
# UNIREP XLNET
# UNIREP CPCPROT
# UNIREP UNIREP
# UNIREP KSEP
# UNIREP PROTVEC
# UNIREP LEARNED-VEC
# UNIREP APAAC
# UNIREP AAC
# UNIREP PFAM
# UNIREP BERT-PFAM
# KSEP ALBERT
# KSEP ESMB1
# KSEP SEQVEC
# KSEP BERT-BFD
# KSEP T5
# KSEP XLNET
# KSEP CPCPROT
# KSEP UNIREP
# KSEP KSEP
# KSEP PROTVEC
# KSEP LEARNED-VEC
# KSEP APAAC
# KSEP AAC
# KSEP PFAM
# KSEP BERT-PFAM
# PROTVEC ALBERT
# PROTVEC ESMB1
# PROTVEC SEQVEC
# PROTVEC BERT-BFD
# PROTVEC T5
# PROTVEC XLNET
# PROTVEC CPCPROT
# PROTVEC UNIREP
# PROTVEC KSEP
# PROTVEC PROTVEC
# PROTVEC LEARNED-VEC
# PROTVEC APAAC
# PROTVEC AAC
# PROTVEC PFAM
# PROTVEC BERT-PFAM
# LEARNED-VEC ALBERT
# LEARNED-VEC ESMB1
# LEARNED-VEC SEQVEC
# LEARNED-VEC BERT-BFD
# LEARNED-VEC T5
# LEARNED-VEC XLNET
# LEARNED-VEC CPCPROT
# LEARNED-VEC UNIREP
# LEARNED-VEC KSEP
# LEARNED-VEC PROTVEC
# LEARNED-VEC LEARNED-VEC
# LEARNED-VEC APAAC
# LEARNED-VEC AAC
# LEARNED-VEC PFAM
# LEARNED-VEC BERT-PFAM
# APAAC ALBERT
# APAAC ESMB1
# APAAC SEQVEC
# APAAC BERT-BFD
# APAAC T5
# APAAC XLNET
# APAAC CPCPROT
# APAAC UNIREP
# APAAC KSEP
# APAAC PROTVEC
# APAAC LEARNED-VEC
# APAAC APAAC
# APAAC AAC
# APAAC PFAM
# APAAC BERT-PFAM
# AAC ALBERT
# AAC ESMB1
# AAC SEQVEC
# AAC BERT-BFD
# AAC T5
# AAC XLNET
# AAC CPCPROT
# AAC UNIREP
# AAC KSEP
# AAC PROTVEC
# AAC LEARNED-VEC
# AAC APAAC
# AAC AAC
# AAC PFAM
# AAC BERT-PFAM
# PFAM ALBERT
# PFAM ESMB1
# PFAM SEQVEC
# PFAM BERT-BFD
# PFAM T5
# PFAM XLNET
# PFAM CPCPROT
# PFAM UNIREP
# PFAM KSEP
# PFAM PROTVEC
# PFAM LEARNED-VEC
# PFAM APAAC
# PFAM AAC
# PFAM PFAM
# PFAM BERT-PFAM
# BERT-PFAM ALBERT
# BERT-PFAM ESMB1
# BERT-PFAM SEQVEC
# BERT-PFAM BERT-BFD
# BERT-PFAM T5
# BERT-PFAM XLNET
# BERT-PFAM CPCPROT
# BERT-PFAM UNIREP
# BERT-PFAM KSEP
# BERT-PFAM PROTVEC
# BERT-PFAM LEARNED-VEC
# BERT-PFAM APAAC
# BERT-PFAM AAC
# BERT-PFAM PFAM
# BERT-PFAM BERT-PFAM
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /media/DATA/serbulent/anaconda3/envs/embedding_similarity/lib/python3.7/site-packages/scipy/stats/morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
#                ALBERT     ESMB1    SEQVEC  BERT-BFD        T5     XLNET  \
# ALBERT       1.000000  0.027344  0.001953  0.001953  0.001953  0.001953
# ESMB1        0.027344  1.000000  0.027344  0.048828  0.019531  0.001953
# SEQVEC       0.001953  0.027344  1.000000  0.769531  0.232422  0.001953
# BERT-BFD     0.001953  0.048828  0.769531  1.000000  0.492188  0.105469
# T5           0.001953  0.019531  0.232422  0.492188  1.000000  0.431641
# XLNET        0.001953  0.001953  0.001953  0.105469  0.431641  1.000000
# CPCPROT      0.001953  0.001953  0.001953  0.003906  0.048828  0.001953
# UNIREP       0.001953  0.001953  0.001953  0.037109  0.064453  0.001953
# KSEP         0.001953  0.001953  0.001953  0.001953  0.003906  0.001953
# PROTVEC      0.001953  0.001953  0.001953  0.001953  0.001953  0.001953
# LEARNED-VEC  0.001953  0.001953  0.001953  0.001953  0.001953  0.001953
# APAAC        0.001953  0.001953  0.001953  0.001953  0.001953  0.001953
# AAC          0.001953  0.001953  0.001953  0.001953  0.001953  0.001953
# PFAM         0.001953  0.001953  0.001953  0.001953  0.001953  0.001953
# BERT-PFAM    0.001953  0.001953  0.001953  0.001953  0.001953  0.001953
#
#               CPCPROT    UNIREP      KSEP   PROTVEC  LEARNED-VEC     APAAC  \
# ALBERT       0.001953  0.001953  0.001953  0.001953     0.001953  0.001953
# ESMB1        0.001953  0.001953  0.001953  0.001953     0.001953  0.001953
# SEQVEC       0.001953  0.001953  0.001953  0.001953     0.001953  0.001953
# BERT-BFD     0.003906  0.037109  0.001953  0.001953     0.001953  0.001953
# T5           0.048828  0.064453  0.003906  0.001953     0.001953  0.001953
# XLNET        0.001953  0.001953  0.001953  0.001953     0.001953  0.001953
# CPCPROT      1.000000  0.845703  0.001953  0.001953     0.001953  0.001953
# UNIREP       0.845703  1.000000  0.001953  0.001953     0.001953  0.001953
# KSEP         0.001953  0.001953  1.000000  0.001953     0.001953  0.001953
# PROTVEC      0.001953  0.001953  0.001953  1.000000     0.064453  0.001953
# LEARNED-VEC  0.001953  0.001953  0.001953  0.064453     1.000000  0.001953
# APAAC        0.001953  0.001953  0.001953  0.001953     0.001953  1.000000
# AAC          0.001953  0.001953  0.001953  0.001953     0.001953  0.193359
# PFAM         0.001953  0.001953  0.001953  0.001953     0.001953  0.001953
# BERT-PFAM    0.001953  0.001953  0.001953  0.001953     0.001953  0.001953
#
#                   AAC      PFAM  BERT-PFAM
# ALBERT       0.001953  0.001953   0.001953
# ESMB1        0.001953  0.001953   0.001953
# SEQVEC       0.001953  0.001953   0.001953
# BERT-BFD     0.001953  0.001953   0.001953
# T5           0.001953  0.001953   0.001953
# XLNET        0.001953  0.001953   0.001953
# CPCPROT      0.001953  0.001953   0.001953
# UNIREP       0.001953  0.001953   0.001953
# KSEP         0.001953  0.001953   0.001953
# PROTVEC      0.001953  0.001953   0.001953
# LEARNED-VEC  0.001953  0.001953   0.001953
# APAAC        0.193359  0.001953   0.001953
# AAC          1.000000  0.001953   0.001953
# PFAM         0.001953  1.000000   0.001953
# BERT-PFAM    0.001953  0.001953   1.000000
